# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Ρύθμιση για να φαίνονται ωραία τα γραφήματα
sns.set(style="whitegrid")

# Σχεδιάζουμε ιστόγραμμα για ΟΛΕΣ τις στήλες
# bins=50: Πόσες "μπάρες" θα έχει το κάθε γράφημα
# figsize=(20,15): Το μέγεθος της εικόνας
df.hist(bins=50, figsize=(20,15))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       5 sns.set(style="whitegrid")
#       7 # Σχεδιάζουμε ιστόγραμμα για ΟΛΕΣ τις στήλες
#       8 # bins=50: Πόσες "μπάρες" θα έχει το κάθε γράφημα
#       9 # figsize=(20,15): Το μέγεθος της εικόνας
# ---> 10 df.hist(bins=50, figsize=(20,15))
#      11 plt.show()
#
# NameError: name 'df' is not defined
